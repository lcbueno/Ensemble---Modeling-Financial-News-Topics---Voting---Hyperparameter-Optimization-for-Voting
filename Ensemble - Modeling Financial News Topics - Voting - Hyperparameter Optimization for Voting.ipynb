# %%
# Versão 2 - Otimização de Hiperpparâmetros para o Voting

# %%
# Imports
import numpy as np
from nltk.corpus import stopwords
from sklearn.datasets import load_files
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.metrics import accuracy_score

# %%
# Carregando os dados
noticias = load_files('dados', encoding = 'utf-8', decode_error = 'replace')

# %%
# Separando variáveis de entrada e saída
X = noticias.data
y = noticias.target

# %%
# Para gravar o resultado
d = {}
d['soft'] = []
d['hard'] = []

# %%
# Loop
for x in range(1,100):

	# Divisão treino/teste
    X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.30, random_state = x)

    # Stop words
    my_stop_words = set(stopwords.words('english'))

    # Vetorização
    vectorizer = TfidfVectorizer(norm = None, stop_words = my_stop_words, max_features = 1000, decode_error = "ignore")

    # Aplica a vetorização
    X_treino_vectors = vectorizer.fit_transform(X_treino)
    X_teste_vectors = vectorizer.transform(X_teste)

    # Cria os modelos base
    modelo1 = LogisticRegression(multi_class = 'multinomial', solver = 'lbfgs', random_state = 30, max_iter = 1000)
    modelo2 = RandomForestClassifier(n_estimators = 1000, max_depth = 100, random_state = 1)
    modelo3 = MultinomialNB()

    # Loop
    for i in ['soft','hard']:
        voting_model = VotingClassifier(estimators = [ ('lg', modelo1), ('rf', modelo2), ('nb', modelo3)], voting = i)
        voting_model = voting_model.fit(X_treino_vectors, y_treino)
        previsoes = voting_model.predict(X_teste_vectors)
        print('-Random State:', x, '-Voting:', i, '-Acurácia :', accuracy_score(y_teste, previsoes))
        d[i].append((x,accuracy_score(y_teste, previsoes)))
    

print('\nMelhores Resultados:')
# Out:
# -Random State: 1 -Voting: soft -Acurácia : 0.968562874251497
# -Random State: 1 -Voting: hard -Acurácia : 0.9670658682634731
# -Random State: 2 -Voting: soft -Acurácia : 0.9730538922155688
# -Random State: 2 -Voting: hard -Acurácia : 0.9775449101796407
# -Random State: 3 -Voting: soft -Acurácia : 0.9745508982035929
# -Random State: 3 -Voting: hard -Acurácia : 0.9790419161676647
# -Random State: 4 -Voting: soft -Acurácia : 0.9700598802395209
# -Random State: 4 -Voting: hard -Acurácia : 0.9745508982035929
# -Random State: 5 -Voting: soft -Acurácia : 0.9625748502994012
# -Random State: 5 -Voting: hard -Acurácia : 0.9670658682634731
# -Random State: 6 -Voting: soft -Acurácia : 0.9565868263473054
# -Random State: 6 -Voting: hard -Acurácia : 0.9655688622754491
# -Random State: 7 -Voting: soft -Acurácia : 0.9670658682634731
# -Random State: 7 -Voting: hard -Acurácia : 0.9655688622754491
# -Random State: 8 -Voting: soft -Acurácia : 0.9760479041916168
# -Random State: 8 -Voting: hard -Acurácia : 0.9835329341317365
# -Random State: 9 -Voting: soft -Acurácia : 0.9805389221556886
# -Random State: 9 -Voting: hard -Acurácia : 0.9790419161676647
# -Random State: 10 -Voting: soft -Acurácia : 0.9595808383233533
# -Random State: 10 -Voting: hard -Acurácia : 0.9670658682634731
# -Random State: 11 -Voting: soft -Acurácia : 0.9670658682634731
# -Random State: 11 -Voting: hard -Acurácia : 0.9730538922155688
# -Random State: 12 -Voting: soft -Acurácia : 0.9790419161676647
# -Random State: 12 -Voting: hard -Acurácia : 0.9805389221556886
# -Random State: 13 -Voting: soft -Acurácia : 0.9610778443113772
# -Random State: 13 -Voting: hard -Acurácia : 0.9700598802395209
# -Random State: 14 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 14 -Voting: hard -Acurácia : 0.968562874251497
# -Random State: 15 -Voting: soft -Acurácia : 0.9730538922155688
# -Random State: 15 -Voting: hard -Acurácia : 0.9760479041916168
# -Random State: 16 -Voting: soft -Acurácia : 0.9700598802395209
# -Random State: 16 -Voting: hard -Acurácia : 0.9745508982035929
# -Random State: 17 -Voting: soft -Acurácia : 0.9625748502994012
# -Random State: 17 -Voting: hard -Acurácia : 0.9655688622754491
# -Random State: 18 -Voting: soft -Acurácia : 0.968562874251497
# -Random State: 18 -Voting: hard -Acurácia : 0.9670658682634731
# -Random State: 19 -Voting: soft -Acurácia : 0.9625748502994012
# -Random State: 19 -Voting: hard -Acurácia : 0.9730538922155688
# -Random State: 20 -Voting: soft -Acurácia : 0.9700598802395209
# -Random State: 20 -Voting: hard -Acurácia : 0.9775449101796407
# -Random State:
-Voting: hard -Acurácia : 0.9670658682634731
# -Random State: 76 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 76 -Voting: hard -Acurácia : 0.9775449101796407
# -Random State: 77 -Voting: soft -Acurácia : 0.9625748502994012
# -Random State: 77 -Voting: hard -Acurácia : 0.9655688622754491
# -Random State: 78 -Voting: soft -Acurácia : 0.9595808383233533
# -Random State: 78 -Voting: hard -Acurácia : 0.9625748502994012
# -Random State: 79 -Voting: soft -Acurácia : 0.9760479041916168
# -Random State: 79 -Voting: hard -Acurácia : 0.9730538922155688
# -Random State: 80 -Voting: soft -Acurácia : 0.9625748502994012
# -Random State: 80 -Voting: hard -Acurácia : 0.9700598802395209
# -Random State: 81 -Voting: soft -Acurácia : 0.9700598802395209
# -Random State: 81 -Voting: hard -Acurácia : 0.9730538922155688
# -Random State: 82 -Voting: soft -Acurácia : 0.968562874251497
# -Random State: 82 -Voting: hard -Acurácia : 0.9670658682634731
# -Random State: 83 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 83 -Voting: hard -Acurácia : 0.9775449101796407
# -Random State: 84 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 84 -Voting: hard -Acurácia : 0.9760479041916168
# -Random State: 85 -Voting: soft -Acurácia : 0.9670658682634731
# -Random State: 85 -Voting: hard -Acurácia : 0.968562874251497
# -Random State: 86 -Voting: soft -Acurácia : 0.9700598802395209
# -Random State: 86 -Voting: hard -Acurácia : 0.9700598802395209
# -Random State: 87 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 87 -Voting: hard -Acurácia : 0.9790419161676647
# -Random State: 88 -Voting: soft -Acurácia : 0.9655688622754491
# -Random State: 88 -Voting: hard -Acurácia : 0.9715568862275449
# -Random State: 89 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 89 -Voting: hard -Acurácia : 0.9760479041916168
# -Random State: 90 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 90 -Voting: hard -Acurácia : 0.9745508982035929
# -Random State: 91 -Voting: soft -Acurácia : 0.9790419161676647
# -Random State: 91 -Voting: hard -Acurácia : 0.9745508982035929
# -Random State: 92 -Voting: soft -Acurácia : 0.968562874251497
# -Random State: 92 -Voting: hard -Acurácia : 0.9640718562874252
# -Random State: 93 -Voting: soft -Acurácia : 0.9865269461077845
# -Random State: 93 -Voting: hard -Acurácia : 0.9880239520958084
# -Random State: 94 -Voting: soft -Acurácia : 0.9775449101796407
# -Random State: 94 -Voting: hard -Acurácia : 0.9790419161676647
# -Random State: 95 -Voting: soft -Acurácia : 0.9715568862275449
# -Random State: 95 -Voting: hard -Acurácia : 0.9715568862275449
# -Random State: 96 -Voting: soft -Acurácia : 0.9700598802395209
# -Random State: 96 -Voting: hard -Acurácia : 0.9715568862275449
# -Random State: 97 -Voting: soft -Acurácia : 0.9670658682634731
# -Random State: 97 -Voting: hard -Acurácia : 0.9700598802395209
# -Random State: 98 -Voting: soft -Acurácia : 0.9640718562874252
# -Random State: 98 -Voting: hard -Acurácia : 0.9655688622754491
# -Random State: 99 -Voting: soft -Acurácia : 0.9655688622754491
# -Random State: 99 -Voting: hard -Acurácia : 0.9700598802395209
#
# Melhores Resultados:

# %%
# Extrai os melhores resultados
h = max(d['hard'], key = lambda x:x[1])
s = max(d['soft'], key = lambda x:x[1])

# %%
# Print
print('-Random State:',h[0], '-Voting:hard', '-Acurácia:', h[1])
print('-Random State:',s[0], '-Voting:soft', '-Acurácia:', s[1])

print('\n')
# Out:
# -Random State: 74 -Voting:hard -Acurácia: 0.9880239520958084
# -Random State: 93 -Voting:soft -Acurácia: 0.9865269461077845
